# %% [markdown]
# <a href="https://colab.research.google.com/github/pikijhon/Analisys_Big_Data/blob/main/menampilkan_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
from matplotlib import style

x = [0, 1, 2, 3, 4, 5]
y = [24.5, 23.18, 25.9, 30.5, 22.3, 24.6]

fig, ax = plt.subplots()

ax.bar(x, y, align='center')

ax.set_title('Bahasa pemrograman favorit')
ax.set_ylabel('Pengguna')
ax.set_xlabel('Bahasa')

ax.set_xticks(x)
ax.set_xticklabels(("Phyton", "java", "javascript", "C#", "php", "c++"))

plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Teknisi', 'Guru', 'Pegawai Kantor', 'Pedagang']
quantity = [3, 10, 12, 11]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

plt.title('Daftar Pekerjaan lulusan Darmajaya')
plt.pie(quantity, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('Jumlah_Penduduk_Miskin.xlsx')
data
# Out:
#                 Wilayah     2021     2022    2023
# 0         Lampung Barat    39.36    36.20   34.73
# 1             Tanggamus    71.89    67.43   65.18
# 2       Lampung Selatan   145.85   136.21  133.67
# 3         Lampung Timur   159.79   149.12  148.26
# 4        Lampung Tengah   155.77   143.34  140.29
# 5         Lampung Utara   121.91   114.67  107.21
# 6             Way Kanan    59.89    54.28   51.26
# 7         Tulang Bawang    44.53    39.19   37.83
# 8             Pesawaran    68.31    63.17   59.29
# 9             Pringsewu    41.04    38.18   37.60
# 10               Mesuji    15.24    13.88   13.71
# 11  Tulang Bawang Barat    23.03    20.72   20.32
# 12        Pesisir Barat    23.23    21.85   21.45
# 13       Bandar Lampung    98.76    90.51   87.08
# 14                Metro    15.32    13.68   12.79
# 15     Provinsi Lampung  1083.93  1002.41  970.67

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('Jumlah_Penduduk_Miskin.xlsx')
wilayah = data['Wilayah']
jumlah = data['2023']

fig, ax = plt.subplots(figsize=(10,8))

ax.bar(wilayah, jumlah, align='center')

ax.set_title('Tingkat Kemiskinan di Privinsi Lampung 2023')
ax.set_ylabel('Jumlah')
ax.set_xlabel('wilayah')

ax.set_xticks(wilayah)
ax.set_xticklabels(wilayah, rotation=90)

plt.show()
